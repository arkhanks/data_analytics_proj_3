# %%
import pandas as pd

# %%
# Import csv file and read it into a dataframe
csv_file_path = '../Resources/IEA Global EV Data 2024.csv'
df =pd.read_csv(csv_file_path)

# Inspect the first or last few rows of the dataset to see that the data loaded properly and what you're working with
df.head(40)
# Out:
#        region    category           parameter  mode               powertrain  \
# 0   Australia  Historical      EV stock share  Cars                       EV
# 1   Australia  Historical      EV sales share  Cars                       EV
# 2   Australia  Historical            EV sales  Cars                      BEV
# 3   Australia  Historical            EV stock  Cars                      BEV
# 4   Australia  Historical            EV stock  Cars                      BEV
# 5   Australia  Historical            EV sales  Cars                      BEV
# 6   Australia  Historical      EV sales share  Cars                       EV
# 7   Australia  Historical      EV stock share  Cars                       EV
# 8   Australia  Historical            EV stock  Cars                     PHEV
# 9   Australia  Historical            EV sales  Cars                     PHEV
# 10  Australia  Historical            EV sales  Cars                     PHEV
# 11  Australia  Historical            EV stock  Cars                     PHEV
# 12  Australia  Historical      EV stock share  Cars                       EV
# 13  Australia  Historical      EV sales share  Cars                       EV
# 14  Australia  Historical            EV sales  Cars                      BEV
# 15  Australia  Historical            EV stock  Cars                      BEV
# 16  Australia  Historical            EV stock  Cars                      BEV
# 17  Australia  Historical            EV sales  Cars                      BEV
# 18  Australia  Historical      EV sales share  Cars                       EV
# 19  Australia  Historical      EV stock share  Cars                       EV
# 20  Australia  Historical            EV stock  Cars                     PHEV
# 21  Australia  Historical            EV sales  Cars                     PHEV
# 22  Australia  Historical            EV sales  Cars                     PHEV
# 23  Australia  Historical            EV stock  Cars                     PHEV
# 24  Australia  Historical      EV stock share  Cars                       EV
# 25  Australia  Historical      EV sales share  Cars                       EV
# 26  Australia  Historical            EV sales  Cars                      BEV
# 27  Australia  Historical            EV stock  Cars                      BEV
# 28  Australia  Historical            EV stock  Cars                      BEV
# 29  Australia  Historical            EV sales  Cars                      BEV
# 30  Australia  Historical      EV sales share  Cars                       EV
# 31  Australia  Historical      EV stock share  Cars                       EV
# 32  Australia  Historical            EV stock  Cars                     PHEV
# 33  Australia  Historical            EV sales  Cars                     PHEV
# 34  Australia  Historical            EV sales  Cars                     PHEV
# 35  Australia  Historical            EV stock  Cars                     PHEV
# 36  Australia  Historical      EV stock share  Cars                       EV
# 37  Australia  Historical      EV sales share  Cars                       EV
# 38  Australia  Historical  EV charging points    EV  Publicly available fast
# 39  Australia  Historical  EV charging points    EV  Publicly available slow
#
#     year             unit       value
# 0   2011          percent     0.00039
# 1   2011          percent     0.00650
# 2   2011         Vehicles    49.00000
# 3   2011         Vehicles    49.00000
# 4   2012         Vehicles   220.00000
# 5   2012         Vehicles   170.00000
# 6   2012          percent     0.03000
# 7   2012          percent     0.00240
# 8   2012         Vehicles    80.00000
# 9   2012         Vehicles    80.00000
# 10  2013         Vehicles   100.00000
# 11  2013         Vehicles   180.00000
# 12  2013          percent     0.00460
# 13  2013          percent     0.03400
# 14  2013         Vehicles   190.00000
# 15  2013         Vehicles   410.00000
# 16  2014         Vehicles   780.00000
# 17  2014         Vehicles   370.00000
# 18  2014          percent     0.16000
# 19  2014          percent     0.01400
# 20  2014         Vehicles  1100.00000
# 21  2014         Vehicles   950.00000
# 22  2015         Vehicles  1000.00000
# 23  2015         Vehicles  2100.00000
# 24  2015          percent     0.02700
# 25  2015          percent     0.20000
# 26  2015         Vehicles   760.00000
# 27  2015         Vehicles  1500.00000
# 28  2016         Vehicles  2200.00000
# 29  2016         Vehicles   670.00000
# 30  2016          percent     0.15000
# 31  2016          percent     0.03700
# 32  2016         Vehicles  2800.00000
# 33  2016         Vehicles   700.00000
# 34  2017         Vehicles  1100.00000
# 35  2017         Vehicles  3900.00000
# 36  2017          percent     0.05200
# 37  2017          percent     0.26000
# 38  2017  charging points    40.00000
# 39  2017  charging points   440.00000

# %%
# get a better idea of the dataset
df.describe()
# Out:
#                year         value
# count  12654.000000  1.265400e+04
# mean    2019.822112  4.273742e+05
# std        5.476494  6.860498e+06
# min     2010.000000  1.200000e-06
# 25%     2016.000000  2.000000e+00
# 50%     2020.000000  1.300000e+02
# 75%     2022.000000  5.500000e+03
# max     2035.000000  4.400000e+08

# %%
# Check how many non null values each column has
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12654 entries, 0 to 12653
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      12654 non-null  object
#  1   category    12654 non-null  object
#  2   parameter   12654 non-null  object
#  3   mode        12654 non-null  object
#  4   powertrain  12654 non-null  object
#  5   year        12654 non-null  int64
#  6   unit        12654 non-null  object
#  7   value       12654 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 791.0+ KB

# %%
# how many rows have data
df.count()
# Out:
# region        12654
# category      12654
# parameter     12654
# mode          12654
# powertrain    12654
# year          12654
# unit          12654
# value         12654
# dtype: int64

# %%
# find the datatypes
df.dtypes
# Out:
# region         object
# category       object
# parameter      object
# mode           object
# powertrain     object
# year            int64
# unit           object
# value         float64
# dtype: object

# %%
# Check for missing values in the dataset
print(df.isnull().sum())
# Out:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64

# %%
# Remove duplicate rows
df = df.drop_duplicates()

# %%
#Check dataset to see if any duplicates were dropped
df.describe()
# Out:
#                year         value
# count  12654.000000  1.265400e+04
# mean    2019.822112  4.273742e+05
# std        5.476494  6.860498e+06
# min     2010.000000  1.200000e-06
# 25%     2016.000000  2.000000e+00
# 50%     2020.000000  1.300000e+02
# 75%     2022.000000  5.500000e+03
# max     2035.000000  4.400000e+08

# %%
# list the  countries/regions where we have data
df['region'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria', 'Canada',
#        'Chile', 'China', 'Colombia', 'Costa Rica', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Estonia', 'EU27', 'Europe',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan',
#        'Korea', 'Latvia', 'Lithuania', 'Luxembourg', 'Mexico',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Rest of the world', 'Romania', 'Seychelles', 'Slovakia',
#        'Slovenia', 'South Africa', 'Spain', 'Sweden', 'Switzerland',
#        'Thailand', 'Turkiye', 'United Arab Emirates', 'United Kingdom',
#        'USA', 'World'], dtype=object)

# %%
# Make dataframe of ev adoption 2023 by ev sales share 
df_2023_evsales = df.loc[
    (df['year']==2023) &
    (df['parameter']== 'EV sales share')
]

# %%
df_2023_evsales.head()
# Out:
#         region    category       parameter    mode powertrain  year     unit  \
# 90   Australia  Historical  EV sales share    Cars         EV  2023  percent
# 201    Austria  Historical  EV sales share    Cars         EV  2023  percent
# 493    Belgium  Historical  EV sales share  Trucks         EV  2023  percent
# 495    Belgium  Historical  EV sales share    Vans         EV  2023  percent
# 497    Belgium  Historical  EV sales share   Buses         EV  2023  percent
#
#      value
# 90    12.0
# 201   26.0
# 493    1.7
# 495    4.6
# 497   62.0

# %%
df_2023_evsales_ordered = df_2023_evsales.sort_values(by='value', ascending = False)
df_2023_evsales_ordered.head(25)
# Out:
#             region          category       parameter   mode powertrain  year  \
# 7922        Norway        Historical  EV sales share   Cars         EV  2023
# 5392       Iceland        Historical  EV sales share   Cars         EV  2023
# 10203  Switzerland        Historical  EV sales share  Buses         EV  2023
# 497        Belgium        Historical  EV sales share  Buses         EV  2023
# 9936        Sweden        Historical  EV sales share   Cars         EV  2023
# 4496       Finland        Historical  EV sales share   Cars         EV  2023
# 7928        Norway        Historical  EV sales share  Buses         EV  2023
# 1859         China        Historical  EV sales share  Buses         EV  2023
# 1924         China    Projection-APS  EV sales share  Buses         EV  2023
# 1828         China  Projection-STEPS  EV sales share  Buses         EV  2023
# 2634       Denmark        Historical  EV sales share   Cars         EV  2023
# 4501       Finland        Historical  EV sales share  Buses         EV  2023
# 507        Belgium        Historical  EV sales share   Cars         EV  2023
# 1824         China  Projection-STEPS  EV sales share   Cars         EV  2023
# 1855         China        Historical  EV sales share   Cars         EV  2023
# 1834         China    Projection-APS  EV sales share   Cars         EV  2023
# 8307      Portugal        Historical  EV sales share  Buses         EV  2023
# 7484   Netherlands        Historical  EV sales share   Cars         EV  2023
# 7041    Luxembourg        Historical  EV sales share   Cars         EV  2023
# 8305      Portugal        Historical  EV sales share   Cars         EV  2023
# 7488   Netherlands        Historical  EV sales share  Buses         EV  2023
# 10201  Switzerland        Historical  EV sales share   Cars         EV  2023
# 7926        Norway        Historical  EV sales share   Vans         EV  2023
# 6133       Ireland        Historical  EV sales share   Cars         EV  2023
# 201        Austria        Historical  EV sales share   Cars         EV  2023
#
#           unit  value
# 7922   percent   93.0
# 5392   percent   71.0
# 10203  percent   65.0
# 497    percent   62.0
# 9936   percent   60.0
# 4496   percent   54.0
# 7928   percent   53.0
# 1859   percent   50.0
# 1924   percent   50.0
# 1828   percent   50.0
# 2634   percent   46.0
# 4501   percent   43.0
# 507    percent   41.0
# 1824   percent   38.0
# 1855   percent   38.0
# 1834   percent   38.0
# 8307   percent   36.0
# 7484   percent   35.0
# 7041   percent   32.0
# 8305   percent   32.0
# 7488   percent   31.0
# 10201  percent   30.0
# 7926   percent   29.0
# 6133   percent   27.0
# 201    percent   26.0
