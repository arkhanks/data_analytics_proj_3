# %%
import pandas as pd

# %%
# Import csv file and read it into a dataframe
csv_file_path = '../Resources/IEA Global EV Data 2024.csv'
df =pd.read_csv(csv_file_path)

# Inspect the first or last few rows of the dataset to see that the data loaded properly and what you're working with
df.tail(40)
# Out:
#       region          category           parameter    mode  \
# 12614  World  Projection-STEPS            EV sales   Buses
# 12615  World  Projection-STEPS            EV sales  Trucks
# 12616  World  Projection-STEPS            EV sales  Trucks
# 12617  World  Projection-STEPS            EV sales  Trucks
# 12618  World  Projection-STEPS            EV sales    Vans
# 12619  World  Projection-STEPS            EV sales    Vans
# 12620  World  Projection-STEPS            EV sales    Vans
# 12621  World  Projection-STEPS            EV sales    Cars
# 12622  World  Projection-STEPS            EV sales    Cars
# 12623  World  Projection-STEPS            EV sales    Cars
# 12624  World  Projection-STEPS            EV stock   Buses
# 12625  World  Projection-STEPS            EV stock   Buses
# 12626  World  Projection-STEPS            EV stock   Buses
# 12627  World  Projection-STEPS            EV stock  Trucks
# 12628  World  Projection-STEPS            EV stock  Trucks
# 12629  World  Projection-STEPS            EV stock  Trucks
# 12630  World  Projection-STEPS            EV stock    Vans
# 12631  World  Projection-STEPS            EV stock    Vans
# 12632  World  Projection-STEPS            EV stock    Vans
# 12633  World  Projection-STEPS            EV stock    Cars
# 12634  World  Projection-STEPS            EV stock    Cars
# 12635  World  Projection-STEPS            EV stock    Cars
# 12636  World    Projection-APS      EV stock share   Buses
# 12637  World    Projection-APS      EV sales share  Trucks
# 12638  World    Projection-APS      EV sales share    Vans
# 12639  World    Projection-APS      EV stock share    Vans
# 12640  World    Projection-APS      EV sales share   Buses
# 12641  World    Projection-APS      EV sales share    Cars
# 12642  World    Projection-APS      EV stock share    Cars
# 12643  World    Projection-APS      EV stock share  Trucks
# 12644  World  Projection-STEPS      EV sales share    Vans
# 12645  World  Projection-STEPS      EV sales share  Trucks
# 12646  World  Projection-STEPS      EV stock share   Buses
# 12647  World  Projection-STEPS      EV sales share   Buses
# 12648  World  Projection-STEPS      EV stock share    Vans
# 12649  World  Projection-STEPS      EV sales share    Cars
# 12650  World  Projection-STEPS      EV stock share    Cars
# 12651  World    Projection-APS  EV charging points      EV
# 12652  World    Projection-APS  EV charging points      EV
# 12653  World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain  year             unit        value
# 12614                     PHEV  2035         Vehicles      82000.0
# 12615                      BEV  2035         Vehicles    1700000.0
# 12616                     FCEV  2035         Vehicles     190000.0
# 12617                     PHEV  2035         Vehicles     110000.0
# 12618                      BEV  2035         Vehicles    4500000.0
# 12619                     FCEV  2035         Vehicles     170000.0
# 12620                     PHEV  2035         Vehicles     150000.0
# 12621                      BEV  2035         Vehicles   51000000.0
# 12622                     FCEV  2035         Vehicles     200000.0
# 12623                     PHEV  2035         Vehicles    5500000.0
# 12624                      BEV  2035         Vehicles    4100000.0
# 12625                     FCEV  2035         Vehicles     270000.0
# 12626                     PHEV  2035         Vehicles     430000.0
# 12627                      BEV  2035         Vehicles   10000000.0
# 12628                     FCEV  2035         Vehicles     940000.0
# 12629                     PHEV  2035         Vehicles     490000.0
# 12630                      BEV  2035         Vehicles   28000000.0
# 12631                     FCEV  2035         Vehicles     980000.0
# 12632                     PHEV  2035         Vehicles    1400000.0
# 12633                      BEV  2035         Vehicles  390000000.0
# 12634                     FCEV  2035         Vehicles    1200000.0
# 12635                     PHEV  2035         Vehicles   89000000.0
# 12636                       EV  2035          percent         25.0
# 12637                       EV  2035          percent         29.0
# 12638                       EV  2035          percent         63.0
# 12639                       EV  2035          percent         24.0
# 12640                       EV  2035          percent         39.0
# 12641                       EV  2035          percent         68.0
# 12642                       EV  2035          percent         34.0
# 12643                       EV  2035          percent         11.0
# 12644                       EV  2035          percent         41.0
# 12645                       EV  2035          percent         22.0
# 12646                       EV  2035          percent         20.0
# 12647                       EV  2035          percent         29.0
# 12648                       EV  2035          percent         18.0
# 12649                       EV  2035          percent         55.0
# 12650                       EV  2035          percent         31.0
# 12651  Publicly available fast  2035  charging points    9400000.0
# 12652  Publicly available slow  2035  charging points   15000000.0
# 12653                       EV  2035          percent          9.0

# %%
# get a better idea of the dataset
df.describe()
# Out:
#                year         value
# count  12654.000000  1.265400e+04
# mean    2019.822112  4.273742e+05
# std        5.476494  6.860498e+06
# min     2010.000000  1.200000e-06
# 25%     2016.000000  2.000000e+00
# 50%     2020.000000  1.300000e+02
# 75%     2022.000000  5.500000e+03
# max     2035.000000  4.400000e+08

# %%
# Check how many non null values each column has
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12654 entries, 0 to 12653
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      12654 non-null  object
#  1   category    12654 non-null  object
#  2   parameter   12654 non-null  object
#  3   mode        12654 non-null  object
#  4   powertrain  12654 non-null  object
#  5   year        12654 non-null  int64
#  6   unit        12654 non-null  object
#  7   value       12654 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 791.0+ KB

# %%
# how many rows have data
df.count()
# Out:
# region        12654
# category      12654
# parameter     12654
# mode          12654
# powertrain    12654
# year          12654
# unit          12654
# value         12654
# dtype: int64

# %%
# find the datatypes
df.dtypes
# Out:
# region         object
# category       object
# parameter      object
# mode           object
# powertrain     object
# year            int64
# unit           object
# value         float64
# dtype: object

# %%
# Check for missing values in the dataset
print(df.isnull().sum())
# Out:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64

# %%
# Remove duplicate rows
df = df.drop_duplicates()

# %%
#Check dataset to see if any duplicates were dropped
df.describe()
# Out:
#                year         value
# count  12654.000000  1.265400e+04
# mean    2019.822112  4.273742e+05
# std        5.476494  6.860498e+06
# min     2010.000000  1.200000e-06
# 25%     2016.000000  2.000000e+00
# 50%     2020.000000  1.300000e+02
# 75%     2022.000000  5.500000e+03
# max     2035.000000  4.400000e+08

# %%
# list the  countries/regions where we have data
df['region'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria', 'Canada',
#        'Chile', 'China', 'Colombia', 'Costa Rica', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Estonia', 'EU27', 'Europe',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan',
#        'Korea', 'Latvia', 'Lithuania', 'Luxembourg', 'Mexico',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Rest of the world', 'Romania', 'Seychelles', 'Slovakia',
#        'Slovenia', 'South Africa', 'Spain', 'Sweden', 'Switzerland',
#        'Thailand', 'Turkiye', 'United Arab Emirates', 'United Kingdom',
#        'USA', 'World'], dtype=object)
